# %%
import requests
import pandas as pd
from datetime import datetime

#from open openai import OpenAI
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scrape EPL Standings and shooting stats

# %%
standings_url = 'https://fbref.com/en/comps/9/Premier-League-Stats'

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select("table.stats_table")[0]

# %%
links = standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if "/squads/" in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %% [markdown]
# team_urls

# %%
team_url = team_urls[0]
data = requests.get(team_url)

# %%
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches[0]
# Out:
#           Date   Time                 Comp                Round  Day Venue  \
# 0   2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1   2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2   2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3   2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4   2024-09-14  15:00       Premier League          Matchweek 4  Sat  Home
# 5   2024-09-18  20:00         Champions Lg         League phase  Wed  Home
# 6   2024-09-22  16:30       Premier League          Matchweek 5  Sun  Home
# 7   2024-09-24  19:45              EFL Cup          Third round  Tue  Home
# 8   2024-09-28  12:30       Premier League          Matchweek 6  Sat  Away
# 9   2024-10-01  21:00         Champions Lg         League phase  Tue  Away
# 10  2024-10-05  15:00       Premier League          Matchweek 7  Sat  Home
# 11  2024-10-20  14:00       Premier League          Matchweek 8  Sun  Away
# 12  2024-10-23  20:00         Champions Lg         League phase  Wed  Home
# 13  2024-10-26  15:00       Premier League          Matchweek 9  Sat  Home
# 14  2024-11-02  15:00       Premier League         Matchweek 10  Sat  Away
# 15  2024-11-05  20:00         Champions Lg         League phase  Tue  Away
# 16  2024-11-09  15:00       Premier League         Matchweek 11  Sat  Away
# 17  2024-11-23  15:00       Premier League         Matchweek 12  Sat  Home
# 18  2024-11-26  20:00         Champions Lg         League phase  Tue  Home
# 19  2024-11-30  15:00       Premier League         Matchweek 13  Sat  Away
# 20  2024-12-04  19:45       Premier League         Matchweek 14  Wed  Home
# 21  2024-12-07  15:00       Premier League         Matchweek 15  Sat  Away
# 22  2024-12-11  21:00         Champions Lg         League phase  Wed  Away
# 23  2024-12-14  15:00       Premier League         Matchweek 16  Sat  Home
# 24  2024-12-21  15:00       Premier League         Matchweek 17  Sat  Away
# 25  2024-12-26  15:00       Premier League         Matchweek 18  Thu  Home
# 26  2024-12-29  15:00       Premier League         Matchweek 19  Sun  Away
# 27  2025-01-04  15:00       Premier League         Matchweek 20  Sat  Home
# 28  2025-01-14  19:45       Premier League         Matchweek 21  Tue  Away
# 29  2025-01-18  15:00       Premier League         Matchweek 22  Sat  Away
# 30  2025-01-22  21:00         Champions Lg         League phase  Wed  Away
# 31  2025-01-25  15:00       Premier League         Matchweek 23  Sat  Home
# 32  2025-01-29  20:00         Champions Lg         League phase  Wed  Home
# 33  2025-02-01  15:00       Premier League         Matchweek 24  Sat  Away
# 34  2025-02-15  15:00       Premier League         Matchweek 25  Sat  Home
# 35  2025-02-22  15:00       Premier League         Matchweek 26  Sat  Home
# 36  2025-02-25  19:45       Premier League         Matchweek 27  Tue  Away
# 37  2025-03-08  15:00       Premier League         Matchweek 28  Sat  Away
# 38  2025-03-15  15:00       Premier League         Matchweek 29  Sat  Home
# 39  2025-04-02  19:45       Premier League         Matchweek 30  Wed  Home
# 40  2025-04-05  15:00       Premier League         Matchweek 31  Sat  Away
# 41  2025-04-12  15:00       Premier League         Matchweek 32  Sat  Home
# 42  2025-04-19  15:00       Premier League         Matchweek 33  Sat  Away
# 43  2025-04-26  15:00       Premier League         Matchweek 34  Sat  Home
# 44  2025-05-03  15:00       Premier League         Matchweek 35  Sat  Home
# 45  2025-05-10  15:00       Premier League         Matchweek 36  Sat  Away
# 46  2025-05-18  15:00       Premier League         Matchweek 37  Sun  Home
# 47  2025-05-25  16:00       Premier League         Matchweek 38  Sun  Away
#
#    Result     GF     GA              Opponent   xG  xGA  Poss  Attendance  \
# 0       D  1 (7)  1 (6)        Manchester Utd  NaN  NaN  56.0     78146.0
# 1       W      2      0               Chelsea  0.8  1.0  52.0     39818.0
# 2       W      4      1          Ipswich Town  3.3  0.3  75.0         NaN
# 3       W      3      1              West Ham  3.0  0.7  67.0         NaN
# 4     NaN    NaN    NaN             Brentford  NaN  NaN   NaN         NaN
# 5     NaN    NaN    NaN              it Inter  NaN  NaN   NaN         NaN
# 6     NaN    NaN    NaN               Arsenal  NaN  NaN   NaN         NaN
# 7     NaN    NaN    NaN               Watford  NaN  NaN   NaN         NaN
# 8     NaN    NaN    NaN         Newcastle Utd  NaN  NaN   NaN         NaN
# 9     NaN    NaN    NaN  sk Slovan Bratislava  NaN  NaN   NaN         NaN
# 10    NaN    NaN    NaN                Fulham  NaN  NaN   NaN         NaN
# 11    NaN    NaN    NaN                Wolves  NaN  NaN   NaN         NaN
# 12    NaN    NaN    NaN      cz Sparta Prague  NaN  NaN   NaN         NaN
# 13    NaN    NaN    NaN           Southampton  NaN  NaN   NaN         NaN
# 14    NaN    NaN    NaN           Bournemouth  NaN  NaN   NaN         NaN
# 15    NaN    NaN    NaN        pt Sporting CP  NaN  NaN   NaN         NaN
# 16    NaN    NaN    NaN              Brighton  NaN  NaN   NaN         NaN
# 17    NaN    NaN    NaN             Tottenham  NaN  NaN   NaN         NaN
# 18    NaN    NaN    NaN          nl Feyenoord  NaN  NaN   NaN         NaN
# 19    NaN    NaN    NaN             Liverpool  NaN  NaN   NaN         NaN
# 20    NaN    NaN    NaN       Nott'ham Forest  NaN  NaN   NaN         NaN
# 21    NaN    NaN    NaN        Crystal Palace  NaN  NaN   NaN         NaN
# 22    NaN    NaN    NaN           it Juventus  NaN  NaN   NaN         NaN
# 23    NaN    NaN    NaN        Manchester Utd  NaN  NaN   NaN         NaN
# 24    NaN    NaN    NaN           Aston Villa  NaN  NaN   NaN         NaN
# 25    NaN    NaN    NaN               Everton  NaN  NaN   NaN         NaN
# 26    NaN    NaN    NaN        Leicester City  NaN  NaN   NaN         NaN
# 27    NaN    NaN    NaN              West Ham  NaN  NaN   NaN         NaN
# 28    NaN    NaN    NaN             Brentford  NaN  NaN   NaN         NaN
# 29    NaN    NaN    NaN          Ipswich Town  NaN  NaN   NaN         NaN
# 30    NaN    NaN    NaN          fr Paris S-G  NaN  NaN   NaN         NaN
# 31    NaN    NaN    NaN               Chelsea  NaN  NaN   NaN         NaN
# 32    NaN    NaN    NaN        be Club Brugge  NaN  NaN   NaN         NaN
# 33    NaN    NaN    NaN               Arsenal  NaN  NaN   NaN         NaN
# 34    NaN    NaN    NaN         Newcastle Utd  NaN  NaN   NaN         NaN
# 35    NaN    NaN    NaN             Liverpool  NaN  NaN   NaN         NaN
# 36    NaN    NaN    NaN             Tottenham  NaN  NaN   NaN         NaN
# 37    NaN    NaN    NaN       Nott'ham Forest  NaN  NaN   NaN         NaN
# 38    NaN    NaN    NaN              Brighton  NaN  NaN   NaN         NaN
# 39    NaN    NaN    NaN        Leicester City  NaN  NaN   NaN         NaN
# 40    NaN    NaN    NaN        Manchester Utd  NaN  NaN   NaN         NaN
# 41    NaN    NaN    NaN        Crystal Palace  NaN  NaN   NaN         NaN
# 42    NaN    NaN    NaN               Everton  NaN  NaN   NaN         NaN
# 43    NaN    NaN    NaN           Aston Villa  NaN  NaN   NaN         NaN
# 44    NaN    NaN    NaN                Wolves  NaN  NaN   NaN         NaN
# 45    NaN    NaN    NaN           Southampton  NaN  NaN   NaN         NaN
# 46    NaN    NaN    NaN           Bournemouth  NaN  NaN   NaN         NaN
# 47    NaN    NaN    NaN                Fulham  NaN  NaN   NaN         NaN
#
#             Captain Formation Opp Formation         Referee  Match Report  \
# 0        Rúben Dias     4-3-3       4-2-3-1  Jarred Gillett  Match Report
# 1   Kevin De Bruyne   3-2-4-1       4-2-3-1             NaN  Match Report
# 2   Kevin De Bruyne   3-2-4-1         5-4-1             NaN  Match Report
# 3   Kevin De Bruyne   3-2-4-1       4-2-3-1  Michael Oliver  Match Report
# 4               NaN       NaN           NaN             NaN  Head-to-Head
# 5               NaN       NaN           NaN             NaN  Head-to-Head
# 6               NaN       NaN           NaN             NaN  Head-to-Head
# 7               NaN       NaN           NaN             NaN  Head-to-Head
# 8               NaN       NaN           NaN             NaN  Head-to-Head
# 9               NaN       NaN           NaN             NaN  Head-to-Head
# 10              NaN       NaN           NaN             NaN  Head-to-Head
# 11              NaN       NaN           NaN             NaN  Head-to-Head
# 12              NaN       NaN           NaN             NaN  Head-to-Head
# 13              NaN       NaN           NaN             NaN  Head-to-Head
# 14              NaN       NaN           NaN             NaN  Head-to-Head
# 15              NaN       NaN           NaN             NaN  Head-to-Head
# 16              NaN       NaN           NaN             NaN  Head-to-Head
# 17              NaN       NaN           NaN             NaN  Head-to-Head
# 18              NaN       NaN           NaN             NaN  Head-to-Head
# 19              NaN       NaN           NaN             NaN  Head-to-Head
# 20              NaN       NaN           NaN             NaN  Head-to-Head
# 21              NaN       NaN           NaN             NaN  Head-to-Head
# 22              NaN       NaN           NaN             NaN  Head-to-Head
# 23              NaN       NaN           NaN             NaN  Head-to-Head
# 24              NaN       NaN           NaN             NaN  Head-to-Head
# 25              NaN       NaN           NaN             NaN  Head-to-Head
# 26              NaN       NaN           NaN             NaN  Head-to-Head
# 27              NaN       NaN           NaN             NaN  Head-to-Head
# 28              NaN       NaN           NaN             NaN  Head-to-Head
# 29              NaN       NaN           NaN             NaN  Head-to-Head
# 30              NaN       NaN           NaN             NaN  Head-to-Head
# 31              NaN       NaN           NaN             NaN  Head-to-Head
# 32              NaN       NaN           NaN             NaN  Head-to-Head
# 33              NaN       NaN           NaN             NaN  Head-to-Head
# 34              NaN       NaN           NaN             NaN  Head-to-Head
# 35              NaN       NaN           NaN             NaN  Head-to-Head
# 36              NaN       NaN           NaN             NaN  Head-to-Head
# 37              NaN       NaN           NaN             NaN  Head-to-Head
# 38              NaN       NaN           NaN             NaN  Head-to-Head
# 39              NaN       NaN           NaN             NaN  Head-to-Head
# 40              NaN       NaN           NaN             NaN  Head-to-Head
# 41              NaN       NaN           NaN             NaN  Head-to-Head
# 42              NaN       NaN           NaN             NaN  Head-to-Head
# 43              NaN       NaN           NaN             NaN  Head-to-Head
# 44              NaN       NaN           NaN             NaN  Head-to-Head
# 45              NaN       NaN           NaN             NaN  Head-to-Head
# 46              NaN       NaN           NaN             NaN  Head-to-Head
# 47              NaN       NaN           NaN             NaN  Head-to-Head
#
#                                                 Notes
# 0   Manchester City won on penalty kicks following...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/shooting/" in l]
# Out:
# ['/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match = "Shooting")[0]

# %%
shooting.head()
# Out:
#   For Manchester City                                                        \
#                  Date   Time                 Comp                Round  Day
# 0          2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat
# 1          2024-08-18  16:30       Premier League          Matchweek 1  Sun
# 2          2024-08-24  15:00       Premier League          Matchweek 2  Sat
# 3          2024-08-31  17:30       Premier League          Matchweek 3  Sat
# 4                 NaN    NaN                  NaN                  NaN  NaN
#
#                                               ... Standard                \
#   Venue Result     GF     GA        Opponent  ...     Dist   FK PK PKatt
# 0  Home      D  1 (7)  1 (6)  Manchester Utd  ...      NaN  NaN  0     0
# 1  Away      W      2      0         Chelsea  ...     19.1  0.0  0     0
# 2  Home      W      4      1    Ipswich Town  ...     17.8  1.0  1     1
# 3  Away      W      3      1        West Ham  ...     15.0  1.0  0     0
# 4   NaN     --    NaN    NaN             NaN  ...     16.7  2.0  1     1
#
#   Expected                            Unnamed: 25_level_0
#         xG npxG npxG/Sh  G-xG np:G-xG        Match Report
# 0      NaN  NaN     NaN   NaN     NaN        Match Report
# 1      0.8  0.8    0.07   1.2     1.2        Match Report
# 2      3.3  2.6    0.20   0.7     0.4        Match Report
# 3      3.0  3.0    0.13   0.0     0.0        Match Report
# 4      NaN  NaN    0.13  10.0     9.0                 NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Cleaning  dataframe

# %%
shooting.columns = shooting.columns.droplevel()
shooting.head()
# Out:
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4         NaN    NaN                  NaN                  NaN  NaN   NaN
#
#   Result     GF     GA        Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  \
# 0      D  1 (7)  1 (6)  Manchester Utd  ...   NaN  NaN   0      0  NaN   NaN
# 1      W      2      0         Chelsea  ...  19.1  0.0   0      0  0.8   0.8
# 2      W      4      1    Ipswich Town  ...  17.8  1.0   1      1  3.3   2.6
# 3      W      3      1        West Ham  ...  15.0  1.0   0      0  3.0   3.0
# 4     --    NaN    NaN             NaN  ...  16.7  2.0   1      1  NaN   NaN
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# 0      NaN   NaN      NaN  Match Report
# 1     0.07   1.2      1.2  Match Report
# 2     0.20   0.7      0.4  Match Report
# 3     0.13   0.0      0.0  Match Report
# 4     0.13  10.0      9.0           NaN
#
# [5 rows x 26 columns]

# %%
#merge the match and shooting

# %%
team_data = matches[0].merge(shooting[["Date","Sh", "SoT","Dist","FK","PK","PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
#
#   Result     GF     GA        Opponent  ...  Opp Formation         Referee  \
# 0      D  1 (7)  1 (6)  Manchester Utd  ...        4-2-3-1  Jarred Gillett
# 1      W      2      0         Chelsea  ...        4-2-3-1             NaN
# 2      W      4      1    Ipswich Town  ...          5-4-1             NaN
# 3      W      3      1        West Ham  ...        4-2-3-1  Michael Oliver
#
#    Match Report                                              Notes  Sh SoT  \
# 0  Match Report  Manchester City won on penalty kicks following...   9   1
# 1  Match Report                                                NaN  11   5
# 2  Match Report                                                NaN  13   4
# 3  Match Report                                                NaN  23   8
#
#    Dist   FK PK PKatt
# 0   NaN  NaN  0     0
# 1  19.1  0.0  0     0
# 2  17.8  1.0  1     1
# 3  15.0  1.0  0     0
#
# [4 rows x 26 columns]
